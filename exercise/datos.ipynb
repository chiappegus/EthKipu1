# %% [markdown]
# EDP ETH Kipu - Talento Tech - 2025 - Comisión PM 2 - Clase 12 - Parte 1

# %% [markdown]
# https://www.youtube.com/watch?v=dVxu0alH2ys&t=214s

# %% [markdown]
# https://github.com/DigiCris/SCIntearctive/tree/main

# %% [markdown]
# https://github.com/DigiCris/SCIntearctive/tree/main/Exercises/3_Interfaces

# %% [markdown]
# ![image.png](attachment:image.png)
